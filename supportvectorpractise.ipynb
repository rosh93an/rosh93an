# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.tree import DecisionTreeClassifier
import warnings 
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv("bank.csv")

# %%
df
# Out:
#        age  job  marital  education  default  balance  housing  loan  contact  \
# 0       59    0        1          1        0     2343        1     0        2
# 1       56    0        1          1        0       45        0     0        2
# 2       41    9        1          1        0     1270        1     0        2
# 3       55    7        1          1        0     2476        1     0        2
# 4       54    0        1          2        0      184        0     0        2
# ...    ...  ...      ...        ...      ...      ...      ...   ...      ...
# 11157   33    1        2          0        0        1        1     0        0
# 11158   39    7        1          1        0      733        0     0        2
# 11159   32    9        2          1        0       29        0     0        0
# 11160   43    9        1          1        0        0        0     1        0
# 11161   34    9        1          1        0        0        0     0        0
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11162 entries, 0 to 11161
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        11162 non-null  int64
#  1   job        11162 non-null  int64
#  2   marital    11162 non-null  int64
#  3   education  11162 non-null  int64
#  4   default    11162 non-null  int64
#  5   balance    11162 non-null  int64
#  6   housing    11162 non-null  int64
#  7   loan       11162 non-null  int64
#  8   contact    11162 non-null  int64
#  9   day        11162 non-null  int64
#  10  month      11162 non-null  int64
#  11  duration   11162 non-null  int64
#  12  campaign   11162 non-null  int64
#  13  pdays      11162 non-null  int64
#  14  previous   11162 non-null  int64
#  15  poutcome   11162 non-null  int64
#  16  deposit    11162 non-null  int64
# dtypes: int64(17)
# memory usage: 1.4 MB

# %%
x=df.drop("deposit",axis=1)
y=df["deposit"]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=1)

# %%
from sklearn.svm import LinearSVC

# %%
linsvc=LinearSVC()

# %%
linsvc.fit(x_train,y_train)
# Out:
# LinearSVC()

# %%
linsvc.score(x_train,y_train)
# Out:
# 0.6239600665557404

# %%
y_pred=linsvc.predict(x_train)

# %%
y_pred
# Out:
# array([1, 1, 1, ..., 1, 1, 1], dtype=int64)

# %%
linsvc.score(x_test,y_test)
# Out:
# 0.6270528515974918

# %%
y_predtest=linsvc.predict(x_test)

# %%
y_predtest
# Out:
# array([1, 0, 1, ..., 1, 1, 0], dtype=int64)

# %%
print(classification_report(y_test,y_predtest))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.32      0.47      1760
#            1       0.56      0.97      0.71      1589
#
#     accuracy                           0.63      3349
#    macro avg       0.74      0.64      0.59      3349
# weighted avg       0.75      0.63      0.59      3349

# %% [markdown]
# NON LINEAR SVC #1)polynomial 2)radial bias

# %%
#Polynomial
from sklearn.svm import SVC

# %%
svc=SVC(random_state=1,kernel="poly")

# %%
svc
# Out:
# SVC(kernel='poly', random_state=1)

# %%
svc.fit(x_train,y_train)
# Out:
# SVC(kernel='poly', random_state=1)

# %%
svc.score(x_train,y_train)
# Out:
# 0.5801868680404454

# %%
y_pred1=svc.predict(x_train)

# %%
y_pred1
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
y_predtest1=svc.predict(x_test)

# %%
y_predtest1
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
svc.score(x_test,y_test)
# Out:
# 0.5888324873096447

# %%
print(classification_report(y_test,y_predtest1))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.56      0.98      0.71      1760
#            1       0.86      0.16      0.27      1589
#
#     accuracy                           0.59      3349
#    macro avg       0.71      0.57      0.49      3349
# weighted avg       0.70      0.59      0.50      3349

# %%
svc2=SVC(random_state=1,kernel="rbf")

# %%
svc2.fit(x_train,y_train)
# Out:
# SVC(random_state=1)

# %%
svc2.score(x_train,y_train)
# Out:
# 0.7382567515678996

# %%
y_pred2=svc2.predict(x_train)

# %%
y_pred2
# Out:
# array([1, 1, 0, ..., 0, 1, 1], dtype=int64)

# %%
svc2.score(x_test,y_test)
# Out:
# 0.7414153478650344

# %%
y_predtest2=svc2.predict(x_test)

# %%
y_predtest2
# Out:
# array([0, 0, 1, ..., 0, 0, 0], dtype=int64)

# %%
print(classification_report(y_test,y_predtest2))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.72      0.84      0.77      1760
#            1       0.78      0.63      0.70      1589
#
#     accuracy                           0.74      3349
#    macro avg       0.75      0.74      0.74      3349
# weighted avg       0.75      0.74      0.74      3349

# %% [markdown]
# on this dataset decision tree random forest&boosting was giving us best prediction accuracy so svm is not suitable algorithim for this data.

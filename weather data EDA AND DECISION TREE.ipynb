# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings 
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv("weather_data.csv")

# %%
df
# Out:
#        Temperature  Humidity  Wind Speed  Precipitation (%)    Cloud Cover  \
# 0             14.0        73         9.5               82.0  partly cloudy
# 1             39.0        96         8.5               71.0  partly cloudy
# 2             30.0        64         7.0               16.0          clear
# 3             38.0        83         1.5               82.0          clear
# 4             27.0        74        17.0               66.0       overcast
# ...            ...       ...         ...                ...            ...
# 13195         10.0        74        14.5               71.0       overcast
# 13196         -1.0        76         3.5               23.0         cloudy
# 13197         30.0        77         5.5               28.0       overcast
# 13198          3.0        76        10.0               94.0       overcast
# 13199         -5.0        38         0.0               92.0       overcast
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13200 entries, 0 to 13199
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Temperature           13200 non-null  float64
#  1   Humidity              13200 non-null  int64
#  2   Wind Speed            13200 non-null  float64
#  3   Precipitation (%)     13200 non-null  float64
#  4   Cloud Cover           13200 non-null  object
#  5   Atmospheric Pressure  13200 non-null  float64
#  6   UV Index              13200 non-null  int64
#  7   Season                13200 non-null  object
#  8   Visibility (km)       13200 non-null  float64
#  9   Location              13200 non-null  object
#  10  Weather Type          13200 non-null  object
# dtypes: float64(5), int64(2), object(4)
# memory usage: 1.1+ MB

# %%
df.describe()
# Out:
#         Temperature      Humidity    Wind Speed  Precipitation (%)  \
# count  13200.000000  13200.000000  13200.000000       13200.000000
# mean      19.127576     68.710833      9.832197          53.644394
# std       17.386327     20.194248      6.908704          31.946541
# min      -25.000000     20.000000      0.000000           0.000000
# 25%        4.000000     57.000000      5.000000          19.000000
# 50%       21.000000     70.000000      9.000000          58.000000
# 75%       31.000000     84.000000     13.500000          82.000000
# max      109.000000    109.000000     48.500000         109.000000
#
#        Atmospheric Pressure      UV Index  Visibility (km)
# count          13200.000000  13200.000000     13200.000000
# mean            1005.827896      4.005758         5.462917
# std               37.199589      3.856600         3.371499
# min              800.120000      0.000000         0.000000
# 25%              994.800000      1.000000         3.000000
# ...

# %%
for i in df:
    print(i,";",df[i].unique())
    print("****************************")
# Out:
# Temperature ; [ 14.  39.  30.  38.  27.  32.  -2.   3.  28.  35.  12. -10.  24.  10.
#   33.  43.  13.  -7.  26.   4.  17.  40.   2.  15.  29.  11.  -9.  36.
#   42.  21.  22.  25.  -4.  -1.  -5.  41.  31.  16.  34.  49.  19.  23.
#   20.  -3.  18.   1.   0.  46.  44. -13.  -6.  78.  63.  73.   8. -12.
#  -24.  -8.  60.  48.   5.  51. -14.  50.  37.  54.  47.  70.   9.  66.
#  -16. -15.  59.  80. -19.  52.  45.   6. -18. -11.  74.  76.  55. -20.
#   57.  91.  82. -17.  61.   7.  53.  65.  77.  67.  64.  58.  68.  72.
#   62.  71.  56. 107. -22.  75.  85.  97.  84. -21.  92. -25.  81. 109.
#   98.  94.  90. -23.  88.  99.  69. 100.  89. 102.  86. 108.  87.  95.]
# ****************************
# Humidity ; [ 73  96  64  83  74  55  97  85  45  43  59  87  21  50  27  51  46 102
#   67  88  36  79  72  57  61  70  95  69  90 105  49  37  22  54  66  25
#   91  98  94  41  84  63  75  52  89  47  81  62  31  68  35  78  56  93
# ...

# %%
df.isnull().sum()
# Out:
# Temperature             0
# Humidity                0
# Wind Speed              0
# Precipitation (%)       0
# Cloud Cover             0
# Atmospheric Pressure    0
# UV Index                0
# Season                  0
# Visibility (km)         0
# Location                0
# Weather Type            0
# dtype: int64

# %%
sns.countplot(data=df,x="Weather Type")
plt.show()

# %%
df["Weather Type"].value_counts()
# Out:
# Weather Type
# Rainy     3300
# Cloudy    3300
# Sunny     3300
# Snowy     3300
# Name: count, dtype: int64

# %%
df_num=df.select_dtypes(["int64","float64"])
df_cat=df.select_dtypes("object")

# %%
df_num
# Out:
#        Temperature  Humidity  Wind Speed  Precipitation (%)  \
# 0             14.0        73         9.5               82.0
# 1             39.0        96         8.5               71.0
# 2             30.0        64         7.0               16.0
# 3             38.0        83         1.5               82.0
# 4             27.0        74        17.0               66.0
# ...            ...       ...         ...                ...
# 13195         10.0        74        14.5               71.0
# 13196         -1.0        76         3.5               23.0
# 13197         30.0        77         5.5               28.0
# 13198          3.0        76        10.0               94.0
# 13199         -5.0        38         0.0               92.0
#
#        Atmospheric Pressure  UV Index  Visibility (km)
# 0                   1010.82         2              3.5
# 1                   1011.43         7             10.0
# 2                   1018.72         5              5.5
# ...

# %%
df_cat
# Out:
#          Cloud Cover  Season  Location Weather Type
# 0      partly cloudy  Winter    inland        Rainy
# 1      partly cloudy  Spring    inland       Cloudy
# 2              clear  Spring  mountain        Sunny
# 3              clear  Spring   coastal        Sunny
# 4           overcast  Winter  mountain        Rainy
# ...              ...     ...       ...          ...
# 13195       overcast  Summer  mountain        Rainy
# 13196         cloudy  Winter   coastal        Snowy
# 13197       overcast  Autumn   coastal       Cloudy
# 13198       overcast  Winter    inland        Snowy
# 13199       overcast  Autumn  mountain        Rainy
#
# [13200 rows x 4 columns]

# %%
plt.figure()
sns.countplot(data=df_cat,y="Cloud Cover",palette="mako",
             order=df_cat["Cloud Cover"].value_counts(ascending=True).index)
plt.show()

# %%
for col in df_cat:
    sns.countplot(data=df_cat,y=col,palette="rocket",
             order=df_cat[col].value_counts(ascending=True).index)
    plt.show()

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
pd.get_dummies(df_cat["Cloud Cover"])
# Out:
#        clear  cloudy  overcast  partly cloudy
# 0      False   False     False           True
# 1      False   False     False           True
# 2       True   False     False          False
# 3       True   False     False          False
# 4      False   False      True          False
# ...      ...     ...       ...            ...
# 13195  False   False      True          False
# 13196  False    True     False          False
# 13197  False   False      True          False
# 13198  False   False      True          False
# 13199  False   False      True          False
#
# [13200 rows x 4 columns]

# %%
le.fit_transform(df_cat["Cloud Cover"])
# Out:
# array([3, 3, 0, ..., 2, 2, 2])

# %%
df_cat["Cloud Cover"]=le.fit_transform(df_cat["Cloud Cover"])

# %%
df_cat
# Out:
#        Cloud Cover  Season  Location Weather Type
# 0                3  Winter    inland        Rainy
# 1                3  Spring    inland       Cloudy
# 2                0  Spring  mountain        Sunny
# 3                0  Spring   coastal        Sunny
# 4                2  Winter  mountain        Rainy
# ...            ...     ...       ...          ...
# 13195            2  Summer  mountain        Rainy
# 13196            1  Winter   coastal        Snowy
# 13197            2  Autumn   coastal       Cloudy
# 13198            2  Winter    inland        Snowy
# 13199            2  Autumn  mountain        Rainy
#
# [13200 rows x 4 columns]

# %%
for col in df_cat:
    le=LabelEncoder()
    df_cat[col]=le.fit_transform(df_cat[col])

# %%
df_cat
# Out:
#        Cloud Cover  Season  Location  Weather Type
# 0                3       3         1             1
# 1                3       1         1             0
# 2                0       1         2             3
# 3                0       1         0             3
# 4                2       3         2             1
# ...            ...     ...       ...           ...
# 13195            2       2         2             1
# 13196            1       3         0             2
# 13197            2       0         0             0
# 13198            2       3         1             2
# 13199            2       0         2             1
#
# [13200 rows x 4 columns]

# %%
df_num
# Out:
#        Temperature  Humidity  Wind Speed  Precipitation (%)  \
# 0             14.0        73         9.5               82.0
# 1             39.0        96         8.5               71.0
# 2             30.0        64         7.0               16.0
# 3             38.0        83         1.5               82.0
# 4             27.0        74        17.0               66.0
# ...            ...       ...         ...                ...
# 13195         10.0        74        14.5               71.0
# 13196         -1.0        76         3.5               23.0
# 13197         30.0        77         5.5               28.0
# 13198          3.0        76        10.0               94.0
# 13199         -5.0        38         0.0               92.0
#
#        Atmospheric Pressure  UV Index  Visibility (km)
# 0                   1010.82         2              3.5
# 1                   1011.43         7             10.0
# 2                   1018.72         5              5.5
# ...

# %%
dff=pd.concat([df_num, df_cat], axis=1)

# %%
dff
# Out:
#        Temperature  Humidity  Wind Speed  Precipitation (%)  \
# 0             14.0        73         9.5               82.0
# 1             39.0        96         8.5               71.0
# 2             30.0        64         7.0               16.0
# 3             38.0        83         1.5               82.0
# 4             27.0        74        17.0               66.0
# ...            ...       ...         ...                ...
# 13195         10.0        74        14.5               71.0
# 13196         -1.0        76         3.5               23.0
# 13197         30.0        77         5.5               28.0
# 13198          3.0        76        10.0               94.0
# 13199         -5.0        38         0.0               92.0
#
#        Atmospheric Pressure  UV Index  Visibility (km)  Cloud Cover  Season  \
# 0                   1010.82         2              3.5            3       3
# 1                   1011.43         7             10.0            3       1
# ...

# %%
X=dff.drop("Weather Type",axis=1)
Y=dff["Weather Type"]

# %%
X
# Out:
#        Temperature  Humidity  Wind Speed  Precipitation (%)  \
# 0             14.0        73         9.5               82.0
# 1             39.0        96         8.5               71.0
# 2             30.0        64         7.0               16.0
# 3             38.0        83         1.5               82.0
# 4             27.0        74        17.0               66.0
# ...            ...       ...         ...                ...
# 13195         10.0        74        14.5               71.0
# 13196         -1.0        76         3.5               23.0
# 13197         30.0        77         5.5               28.0
# 13198          3.0        76        10.0               94.0
# 13199         -5.0        38         0.0               92.0
#
#        Atmospheric Pressure  UV Index  Visibility (km)  Cloud Cover  Season  \
# 0                   1010.82         2              3.5            3       3
# 1                   1011.43         7             10.0            3       1
# ...

# %%
Y
# Out:
# 0        1
# 1        0
# 2        3
# 3        3
# 4        1
#         ..
# 13195    1
# 13196    2
# 13197    0
# 13198    2
# 13199    1
# Name: Weather Type, Length: 13200, dtype: int32

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.tree import DecisionTreeClassifier

# %%
for col in X:
    sns.distplot(X[col])
    plt.show()

# %%
plt.figure(figsize=(10,6))
sns.heatmap(X.corr(),annot=True)
plt.show()

# %%
for j in X:
    sns.boxplot(data=df,x="Weather Type",y=j,palette="deep")
    plt.show()

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.3,random_state=1)

# %%
dt=DecisionTreeClassifier()

# %%
dt.fit(X_train,Y_train)
# Out:
# DecisionTreeClassifier()

# %%
dt.score(X_train,Y_train)
# Out:
# 1.0

# %%
Y_pred=dt.predict(X_train)

# %%
Y_pred
# Out:
# array([3, 1, 0, ..., 3, 3, 0])

# %%
dt.score(X_test,Y_test)
# Out:
# 0.9075757575757576

# %%
Y_predtest=dt.predict(X_test)

# %%
Y_predtest
# Out:
# array([1, 1, 2, ..., 2, 3, 3])

# %%
print(classification_report(Y_test,Y_predtest))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.89      0.89       996
#            1       0.91      0.89      0.90      1006
#            2       0.92      0.93      0.93       990
#            3       0.90      0.92      0.91       968
#
#     accuracy                           0.91      3960
#    macro avg       0.91      0.91      0.91      3960
# weighted avg       0.91      0.91      0.91      3960
